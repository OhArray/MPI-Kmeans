# %%
import matplotlib.pyplot as plt

# read data points from .txt file
#with open("centroids.out", "r") as f:
    #centroids = [tuple(map(float, line.strip().split())) for line in f]
centroids =     [[416754.906250, 168273.328125],
    [822746.875000, 163671.656250],
    [592366.625000, 572541.125000],
    [844029.812500, 631610.187500],
    [676734.750000, 857857.937500],
    [138851.843750, 558149.437500],
    [168840.781250, 345736.906250],
    [618032.687500, 398739.687500],
    [398870.062500, 404924.093750],
    [865902.375000, 155623.265625],
    [802996.562500, 325779.593750],
    [326800.281250, 818471.687500],
    [654918.625000, 579652.875000],
    [318474.156250, 554534.750000],
    [366175.125000, 574391.687500]
]
    
with open("clustered_data.out", "r") as f:
    clust_label = [tuple(map(float, line.strip().split())) for line in f]
    
with open("s1.txt", "r") as f:
    data = [tuple(map(float, line.strip().split())) for line in f]

# extract x and y coordinates from centroids
x_coords_cent = [point[0] for point in centroids]
y_coords_cent = [point[1] for point in centroids]

# extract x and y coordinates from data points
x_coords_data = [point[0] for point in data]
y_coords_data = [point[1] for point in data]


# extract x and y coordinates from data points
clust_label = [point[0] for point in clust_label]

# create a scatter plot of the data points
plt.scatter(x_coords_data, y_coords_data, s = 5, c = clust_label, cmap = 'nipy_spectral')
plt.plot(x_coords_cent, y_coords_cent, marker='o', ls='none', ms=10, color = 'red')

# add axis labels and title
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Data Points")

# display the plot
plt.show()
